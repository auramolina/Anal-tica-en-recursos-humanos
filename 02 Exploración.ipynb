# %% [markdown]
# # <font color='0C2054'> <b> Librerías

# %%
import pandas as pd
import sqlite3 as sql
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from sklearn import tree
from sklearn.tree import export_text
from sklearn.preprocessing import LabelEncoder
import sys
import matplotlib.pyplot as plt
import joblib

# %%
## Conectar el drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # <font color='0C2054'> <b> Base 2016

# %%
d2016 = pd.read_csv("https://raw.githubusercontent.com/auramolina/Analitica-en-recursos-humanos/main/Datos/df_2016")
d2016.sort_values(by=['EmployeeID'],ascending=1)
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# 5      46      Travel_Rarely  Research & Development                 8
# ...   ...                ...                     ...               ...
# 4381   29      Travel_Rarely  Research & Development                 7
# 4386   33      Travel_Rarely                   Sales                11
# 4388   33      Travel_Rarely                   Sales                 1
# 4391   32      Travel_Rarely                   Sales                23
# 4402   37  Travel_Frequently                   Sales                 2
#
#       Education EducationField  EmployeeID  Gender  JobLevel  \
# 0             2  Life Sciences           1  Female         1
# 2             4          Other           3    Male         4
# 3             5  Life Sciences           4    Male         3
# 4             1        Medical           5    Male         1
# 5             3  Life Sciences           6  Female         4
# ...         ...            ...         ...     ...       ...
# 4381          1  Life Sciences        8792  Female         1
# 4386          4      Marketing        8797    Male         1
# 4388          3  Life Sciences        8799    Male         2
# 4391          1  Life Sciences        8802    Male         3
# 4402          3      Marketing        8813    Male         1
#
#                         JobRole  ... JobInvolvement  PerformanceRating  \
# 0     Healthcare Representative  ...              3                  3
# 2               Sales Executive  ...              3                  3
# 3               Human Resources  ...              2                  3
# 4               Sales Executive  ...              3                  3
# 5             Research Director  ...              3                  3
# ...                         ...  ...            ...                ...
# 4381         Research Scientist  ...              3                  4
# 4386         Research Scientist  ...              2                  4
# 4388                    Manager  ...              3                  3
# 4391  Healthcare Representative  ...              3                  3
# 4402      Laboratory Technician  ...              3                  3
#
#       Attrition  retirementDate  retirementType  resignationReason  \
# 0           NaN             NaN             NaN                NaN
# 2           NaN             NaN             NaN                NaN
# 3           NaN             NaN             NaN                NaN
# 4           NaN             NaN             NaN                NaN
# 5           NaN             NaN             NaN                NaN
# ...         ...             ...             ...                ...
# 4381        NaN             NaN             NaN                NaN
# 4386        NaN             NaN             NaN                NaN
# 4388        NaN             NaN             NaN                NaN
# 4391        NaN             NaN             NaN                NaN
# 4402        NaN             NaN             NaN                NaN
#
#       Attrition:1  retirementDate:1  retirementType:1  resignationReason:1
# 0             NaN               NaN               NaN                  NaN
# 2             NaN               NaN               NaN                  NaN
# 3             NaN               NaN               NaN                  NaN
# 4             NaN               NaN               NaN                  NaN
# 5             NaN               NaN               NaN                  NaN
# ...           ...               ...               ...                  ...
# 4381          NaN               NaN               NaN                  NaN
# 4386          NaN               NaN               NaN                  NaN
# 4388          NaN               NaN               NaN                  NaN
# 4391          NaN               NaN               NaN                  NaN
# 4402          NaN               NaN               NaN                  NaN
#
# [4410 rows x 34 columns]

# %%
d2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   BusinessTravel           4410 non-null   object
#  2   Department               4410 non-null   object
#  3   DistanceFromHome         4410 non-null   int64
#  4   Education                4410 non-null   int64
#  5   EducationField           4410 non-null   object
#  6   EmployeeID               4410 non-null   int64
#  7   Gender                   4410 non-null   object
#  8   JobLevel                 4410 non-null   int64
#  9   JobRole                  4410 non-null   object
#  10  MaritalStatus            4410 non-null   object
#  11  MonthlyIncome            4410 non-null   int64
#  12  NumCompaniesWorked       4391 non-null   float64
#  13  PercentSalaryHike        4410 non-null   int64
#  14  StockOptionLevel         4410 non-null   int64
#  15  TotalWorkingYears        4401 non-null   float64
#  16  TrainingTimesLastYear    4410 non-null   int64
#  17  YearsAtCompany           4410 non-null   int64
#  18  YearsSinceLastPromotion  4410 non-null   int64
#  19  YearsWithCurrManager     4410 non-null   int64
#  20  InfoDate                 4410 non-null   object
#  21  EnvironmentSatisfaction  4385 non-null   float64
#  22  JobSatisfaction          4390 non-null   float64
#  23  WorkLifeBalance          4372 non-null   float64
#  24  JobInvolvement           4410 non-null   int64
#  25  PerformanceRating        4410 non-null   int64
#  26  Attrition                0 non-null      float64
#  27  retirementDate           0 non-null      float64
#  28  retirementType           0 non-null      float64
#  29  resignationReason        0 non-null      float64
#  30  Attrition:1              0 non-null      float64
#  31  retirementDate:1         0 non-null      float64
#  32  retirementType:1         0 non-null      float64
#  33  resignationReason:1      0 non-null      float64
# dtypes: float64(13), int64(14), object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# ## <font color='0C2054'> Duplicados

# %%
display(d2016[d2016.duplicated(keep='last')])
display(d2016[d2016.duplicated(keep='first')])
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, Department, DistanceFromHome, Education, EducationField, EmployeeID, Gender, JobLevel, JobRole, MaritalStatus, MonthlyIncome, NumCompaniesWorked, PercentSalaryHike, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, YearsAtCompany, YearsSinceLastPromotion, YearsWithCurrManager, InfoDate, EnvironmentSatisfaction, JobSatisfaction, WorkLifeBalance, JobInvolvement, PerformanceRating, Attrition, retirementDate, retirementType, resignationReason, Attrition:1, retirementDate:1, retirementType:1, resignationReason:1]
# Index: []
#
# [0 rows x 34 columns]
# Empty DataFrame
# Columns: [Age, BusinessTravel, Department, DistanceFromHome, Education, EducationField, EmployeeID, Gender, JobLevel, JobRole, MaritalStatus, MonthlyIncome, NumCompaniesWorked, PercentSalaryHike, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, YearsAtCompany, YearsSinceLastPromotion, YearsWithCurrManager, InfoDate, EnvironmentSatisfaction, JobSatisfaction, WorkLifeBalance, JobInvolvement, PerformanceRating, Attrition, retirementDate, retirementType, resignationReason, Attrition:1, retirementDate:1, retirementType:1, resignationReason:1]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# ##<font color='0C2054'>Eliminación de columnas</font>
# Se descartan las variables que no aportan información relevante.
# * *InfoDate* y *retirementDate*: no es relevante si ya están separadas por año.
# * Columnas con 100% datos nulos.

# %%
# Drop a variables no necesarias
d2016 = d2016.drop(['InfoDate','Attrition', 'retirementDate', 'retirementType', 'resignationReason', 'Attrition:1', 'retirementDate:1', 'retirementType:1', 'resignationReason:1'], axis=1)
d2016.shape
# Out:
# (4410, 25)

# %% [markdown]
# ##<font color='0C2054'>Nulos</font>

# %%
d2016.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
#Función para imputar datos nulos

def imp_datos (df, variables):
    for variable in variables:
        # Calcula la moda de la variable
        moda = df[variable].mode()[0]  # Selecciona el primer valor de la moda en caso de que haya múltiples modas
        # Imputa los valores nulos con la moda
        df[variable].fillna(moda, inplace=True)
        # Imprime información sobre los valores nulos imputados
        nulos_imputados = df[variable].isnull().sum()
    # Devuelve el DataFrame modificado
    return df

# imputar datos nulos para NumCompaniesWorked, TotalWorkingYears, EnvironmentSatisfaction, JobSatisfaction, WorkLifeBalance
d2015 = imp_datos(d2016, ['NumCompaniesWorked', 'TotalWorkingYears', 'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'])

# %%
d2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   BusinessTravel           4410 non-null   object
#  2   Department               4410 non-null   object
#  3   DistanceFromHome         4410 non-null   int64
#  4   Education                4410 non-null   int64
#  5   EducationField           4410 non-null   object
#  6   EmployeeID               4410 non-null   int64
#  7   Gender                   4410 non-null   object
#  8   JobLevel                 4410 non-null   int64
#  9   JobRole                  4410 non-null   object
#  10  MaritalStatus            4410 non-null   object
#  11  MonthlyIncome            4410 non-null   int64
#  12  NumCompaniesWorked       4410 non-null   float64
#  13  PercentSalaryHike        4410 non-null   int64
#  14  StockOptionLevel         4410 non-null   int64
#  15  TotalWorkingYears        4410 non-null   float64
#  16  TrainingTimesLastYear    4410 non-null   int64
#  17  YearsAtCompany           4410 non-null   int64
#  18  YearsSinceLastPromotion  4410 non-null   int64
#  19  YearsWithCurrManager     4410 non-null   int64
#  20  EnvironmentSatisfaction  4410 non-null   float64
#  21  JobSatisfaction          4410 non-null   float64
#  22  WorkLifeBalance          4410 non-null   float64
#  23  JobInvolvement           4410 non-null   int64
#  24  PerformanceRating        4410 non-null   int64
# dtypes: float64(5), int64(14), object(6)
# memory usage: 861.5+ KB

# %%
d2016
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 4405   42      Travel_Rarely  Research & Development                 5
# 4406   29      Travel_Rarely  Research & Development                 2
# 4407   25      Travel_Rarely  Research & Development                25
# 4408   42      Travel_Rarely                   Sales                18
# 4409   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeID  Gender  JobLevel  \
# 0             2  Life Sciences           1  Female         1
# 1             1  Life Sciences        4412  Female         1
# 2             4          Other           3    Male         4
# 3             5  Life Sciences           4    Male         3
# 4             1        Medical           5    Male         1
# ...         ...            ...         ...     ...       ...
# 4405          4        Medical        4406  Female         1
# 4406          4        Medical        4407    Male         1
# 4407          2  Life Sciences        4408    Male         2
# 4408          2        Medical        4409    Male         1
# 4409          3        Medical        4410    Male         2
#
#                         JobRole  ... TotalWorkingYears  TrainingTimesLastYear  \
# 0     Healthcare Representative  ...               1.0                      6
# 1            Research Scientist  ...               6.0                      3
# 2               Sales Executive  ...               5.0                      2
# 3               Human Resources  ...              13.0                      5
# 4               Sales Executive  ...               9.0                      2
# ...                         ...  ...               ...                    ...
# 4405         Research Scientist  ...              10.0                      5
# 4406      Laboratory Technician  ...              10.0                      2
# 4407            Sales Executive  ...               5.0                      4
# 4408      Laboratory Technician  ...              10.0                      2
# 4409      Laboratory Technician  ...              10.0                      6
#
#       YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                  1                        0                     0
# 1                  5                        1                     4
# 2                  5                        0                     3
# 3                  8                        7                     5
# 4                  6                        0                     4
# ...              ...                      ...                   ...
# 4405               3                        0                     2
# 4406               3                        0                     2
# 4407               4                        1                     2
# 4408               9                        7                     8
# 4409              21                        3                     9
#
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0                         3.0              4.0              2.0
# 1                         3.0              2.0              4.0
# 2                         2.0              2.0              1.0
# 3                         4.0              4.0              3.0
# 4                         4.0              1.0              3.0
# ...                       ...              ...              ...
# 4405                      4.0              1.0              3.0
# 4406                      4.0              4.0              3.0
# 4407                      1.0              3.0              3.0
# 4408                      4.0              1.0              3.0
# 4409                      1.0              3.0              3.0
#
#       JobInvolvement  PerformanceRating
# 0                  3                  3
# 1                  2                  4
# 2                  3                  3
# 3                  2                  3
# 4                  3                  3
# ...              ...                ...
# 4405               3                  3
# 4406               2                  3
# 4407               3                  4
# 4408               2                  3
# 4409               4                  3
#
# [4410 rows x 25 columns]

# %% [markdown]
# # <font color='0C2054'> <b>  Base 2015

# %%
d2015 = pd.read_csv("https://raw.githubusercontent.com/auramolina/Analitica-en-recursos-humanos/main/Datos/df_2015")
d2015.sort_values(by=['EmployeeID'],ascending=1)
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 4381   29      Travel_Rarely  Research & Development                 7
# 4386   33      Travel_Rarely                   Sales                11
# 4388   33      Travel_Rarely                   Sales                 1
# 4391   32      Travel_Rarely                   Sales                23
# 4402   37  Travel_Frequently                   Sales                 2
#
#       Education EducationField  EmployeeID  Gender  JobLevel  \
# 0             2  Life Sciences           1  Female         1
# 1             1  Life Sciences           2  Female         1
# 2             4          Other           3    Male         4
# 3             5  Life Sciences           4    Male         3
# 4             1        Medical           5    Male         1
# ...         ...            ...         ...     ...       ...
# 4381          1  Life Sciences        8792  Female         1
# 4386          4      Marketing        8797    Male         1
# 4388          3  Life Sciences        8799    Male         2
# 4391          1  Life Sciences        8802    Male         3
# 4402          3      Marketing        8813    Male         1
#
#                         JobRole  ...             InfoDate  \
# 0     Healthcare Representative  ...  2015-12-31 00:00:00
# 1            Research Scientist  ...  2015-12-31 00:00:00
# 2               Sales Executive  ...  2015-12-31 00:00:00
# 3               Human Resources  ...  2015-12-31 00:00:00
# 4               Sales Executive  ...  2015-12-31 00:00:00
# ...                         ...  ...                  ...
# 4381         Research Scientist  ...  2015-12-31 00:00:00
# 4386         Research Scientist  ...  2015-12-31 00:00:00
# 4388                    Manager  ...  2015-12-31 00:00:00
# 4391  Healthcare Representative  ...  2015-12-31 00:00:00
# 4402      Laboratory Technician  ...  2015-12-31 00:00:00
#
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0                         3.0              4.0              2.0
# 1                         3.0              2.0              4.0
# 2                         2.0              2.0              1.0
# 3                         4.0              4.0              3.0
# 4                         4.0              1.0              3.0
# ...                       ...              ...              ...
# 4381                      3.0              4.0              2.0
# 4386                      3.0              4.0              1.0
# 4388                      1.0              1.0              4.0
# 4391                      4.0              3.0              1.0
# 4402                      1.0              3.0              3.0
#
#       JobInvolvement  PerformanceRating  Attrition       retirementDate  \
# 0                  3                  3        NaN                  NaN
# 1                  2                  4        Yes  2016-10-15 00:00:00
# 2                  3                  3        NaN                  NaN
# 3                  2                  3        NaN                  NaN
# 4                  3                  3        NaN                  NaN
# ...              ...                ...        ...                  ...
# 4381               3                  4        NaN                  NaN
# 4386               2                  4        NaN                  NaN
# 4388               3                  3        NaN                  NaN
# 4391               3                  3        NaN                  NaN
# 4402               3                  3        NaN                  NaN
#
#       retirementType  resignationReason
# 0                NaN                NaN
# 1        Resignation             Others
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# ...              ...                ...
# 4381             NaN                NaN
# 4386             NaN                NaN
# 4388             NaN                NaN
# 4391             NaN                NaN
# 4402             NaN                NaN
#
# [4410 rows x 30 columns]

# %%
d2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   BusinessTravel           4410 non-null   object
#  2   Department               4410 non-null   object
#  3   DistanceFromHome         4410 non-null   int64
#  4   Education                4410 non-null   int64
#  5   EducationField           4410 non-null   object
#  6   EmployeeID               4410 non-null   int64
#  7   Gender                   4410 non-null   object
#  8   JobLevel                 4410 non-null   int64
#  9   JobRole                  4410 non-null   object
#  10  MaritalStatus            4410 non-null   object
#  11  MonthlyIncome            4410 non-null   int64
#  12  NumCompaniesWorked       4391 non-null   float64
#  13  PercentSalaryHike        4410 non-null   int64
#  14  StockOptionLevel         4410 non-null   int64
#  15  TotalWorkingYears        4401 non-null   float64
#  16  TrainingTimesLastYear    4410 non-null   int64
#  17  YearsAtCompany           4410 non-null   int64
#  18  YearsSinceLastPromotion  4410 non-null   int64
#  19  YearsWithCurrManager     4410 non-null   int64
#  20  InfoDate                 4410 non-null   object
#  21  EnvironmentSatisfaction  4385 non-null   float64
#  22  JobSatisfaction          4390 non-null   float64
#  23  WorkLifeBalance          4372 non-null   float64
#  24  JobInvolvement           4410 non-null   int64
#  25  PerformanceRating        4410 non-null   int64
#  26  Attrition                650 non-null    object
#  27  retirementDate           650 non-null    object
#  28  retirementType           650 non-null    object
#  29  resignationReason        585 non-null    object
# dtypes: float64(5), int64(14), object(11)
# memory usage: 1.0+ MB

# %% [markdown]
# ## <font color='0C2054'> Duplicados

# %%
display(d2015[d2015.duplicated(keep='last')])
display(d2015[d2015.duplicated(keep='first')])
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, Department, DistanceFromHome, Education, EducationField, EmployeeID, Gender, JobLevel, JobRole, MaritalStatus, MonthlyIncome, NumCompaniesWorked, PercentSalaryHike, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, YearsAtCompany, YearsSinceLastPromotion, YearsWithCurrManager, InfoDate, EnvironmentSatisfaction, JobSatisfaction, WorkLifeBalance, JobInvolvement, PerformanceRating, Attrition, retirementDate, retirementType, resignationReason]
# Index: []
#
# [0 rows x 30 columns]
# Empty DataFrame
# Columns: [Age, BusinessTravel, Department, DistanceFromHome, Education, EducationField, EmployeeID, Gender, JobLevel, JobRole, MaritalStatus, MonthlyIncome, NumCompaniesWorked, PercentSalaryHike, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, YearsAtCompany, YearsSinceLastPromotion, YearsWithCurrManager, InfoDate, EnvironmentSatisfaction, JobSatisfaction, WorkLifeBalance, JobInvolvement, PerformanceRating, Attrition, retirementDate, retirementType, resignationReason]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ## <font color='0C2054'> Nulos

# %%
d2015.isnull().sum()
# Out:
# Age                           0
# BusinessTravel                0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeID                    0
# Gender                        0
# JobLevel                      0
# JobRole                       0
# MaritalStatus                 0
# MonthlyIncome                 0
# NumCompaniesWorked           19
# PercentSalaryHike             0
# StockOptionLevel              0
# TotalWorkingYears             9
# TrainingTimesLastYear         0
# YearsAtCompany                0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# InfoDate                      0
# EnvironmentSatisfaction      25
# JobSatisfaction              20
# WorkLifeBalance              38
# JobInvolvement                0
# PerformanceRating             0
# Attrition                  3760
# retirementDate             3760
# retirementType             3760
# resignationReason          3825
# dtype: int64

# %%
#Función para imputar datos nulos

def imp_datos (df, variables):
    for variable in variables:
        # Calcula la moda de la variable
        moda = df[variable].mode()[0]  # Selecciona el primer valor de la moda en caso de que haya múltiples modas
        # Imputa los valores nulos con la moda
        df[variable].fillna(moda, inplace=True)
        # Imprime información sobre los valores nulos imputados
        nulos_imputados = df[variable].isnull().sum()
    # Devuelve el DataFrame modificado
    return df

# imputar datos nulos para NumCompaniesWorked, TotalWorkingYears, EnvironmentSatisfaction, JobSatisfaction, WorkLifeBalance
d2015 = imp_datos(d2015, ['NumCompaniesWorked', 'TotalWorkingYears', 'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'])

# %%
#observar si ya no quedan nulos
d2015.isnull().sum()
# Out:
# Age                           0
# BusinessTravel                0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeID                    0
# Gender                        0
# JobLevel                      0
# JobRole                       0
# MaritalStatus                 0
# MonthlyIncome                 0
# NumCompaniesWorked            0
# PercentSalaryHike             0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# YearsAtCompany                0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# InfoDate                      0
# EnvironmentSatisfaction       0
# JobSatisfaction               0
# WorkLifeBalance               0
# JobInvolvement                0
# PerformanceRating             0
# Attrition                  3760
# retirementDate             3760
# retirementType             3760
# resignationReason          3825
# dtype: int64

# %% [markdown]
# Los datos nulos corresponden a que no hubo retiros en esas entradas de la base de datos, se imputan con "No"

# %%
d2015[['Attrition']] = d2015[['Attrition']].fillna("No")

# %% [markdown]
# ##<font color='0C2054'>Eliminación de columnas</font>
# Se descartan las variables que no aportan información relevante. Se eliminan las fechas de información y de retiro.

# %%
## Se eliminan las variables que no se necesitan o no aportan
d2015 = d2015.drop(['EmployeeID', 'InfoDate', 'retirementDate','retirementType','resignationReason'], axis=1)

# %%
d2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   BusinessTravel           4410 non-null   object
#  2   Department               4410 non-null   object
#  3   DistanceFromHome         4410 non-null   int64
#  4   Education                4410 non-null   int64
#  5   EducationField           4410 non-null   object
#  6   Gender                   4410 non-null   object
#  7   JobLevel                 4410 non-null   int64
#  8   JobRole                  4410 non-null   object
#  9   MaritalStatus            4410 non-null   object
#  10  MonthlyIncome            4410 non-null   int64
#  11  NumCompaniesWorked       4410 non-null   float64
#  12  PercentSalaryHike        4410 non-null   int64
#  13  StockOptionLevel         4410 non-null   int64
#  14  TotalWorkingYears        4410 non-null   float64
#  15  TrainingTimesLastYear    4410 non-null   int64
#  16  YearsAtCompany           4410 non-null   int64
#  17  YearsSinceLastPromotion  4410 non-null   int64
#  18  YearsWithCurrManager     4410 non-null   int64
#  19  EnvironmentSatisfaction  4410 non-null   float64
#  20  JobSatisfaction          4410 non-null   float64
#  21  WorkLifeBalance          4410 non-null   float64
#  22  JobInvolvement           4410 non-null   int64
#  23  PerformanceRating        4410 non-null   int64
#  24  Attrition                4410 non-null   object
# dtypes: float64(5), int64(13), object(7)
# memory usage: 861.5+ KB

# %% [markdown]
# ## <font color='0C2054'> Target </font>
# **Deserción**

# %%
# Target value counts
conteo = d2015['Attrition'].value_counts()

# %%
# Gráfica distribución de Target
plt.bar(conteo.index, conteo.values, color='#0C2054')
plt.title('Distribución de Attrition')
plt.xlabel('Attrition')
plt.ylabel('Conteo')
plt.show()

# %% [markdown]
# Se observa un desequilibrio significativo en la variable objetivo, con un 85,26 % de empleados corresponden a "No" en deserción, lo que indica que se quedaron, mientras que solo el 17,74 % están marcados como "Yes", lo que indica que se fueron. Este desbalanceo muestra que la mayoría de los empleados tienden a quedarse en la empresa, lo que podría influir en las predicciones del modelo y requerir un manejo para una mayor precisión.

# %% [markdown]
# # <font color='0C2054'> <b>  Exploración variables númericas </font></b>
# * Los empleados se encuentran entre los 18 a 60 años de edad, lo que indica personal variado en términos de experiencia.
# * El ingreso mensual muestra una variabilidad significativa, ya que algunos empleados ganan tan solo 10 090 mientras que otros ganan hasta 199 999, lo que muestra disparidad en el salario, la cual puede estar influenciada por factores como el puesto de trabajo, el nivel y la antigüedad.
# * Los años en la empresa también varían considerablemente, ya que algunos empleados son nuevos empleados (0 años) y otros tienen hasta 40 años de antigüedad.

# %% [markdown]
# ## <font color='0C2054'> Descripción

# %%
d2015.describe()
# Out:
#                Age  DistanceFromHome    Education     JobLevel  MonthlyIncome  \
# count  4410.000000       4410.000000  4410.000000  4410.000000    4410.000000
# mean     36.923810          9.192517     2.912925     2.063946   65029.312925
# std       9.133301          8.105026     1.023933     1.106689   47068.888559
# min      18.000000          1.000000     1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000     1.000000   29110.000000
# 50%      36.000000          7.000000     3.000000     2.000000   49190.000000
# 75%      43.000000         14.000000     4.000000     3.000000   83800.000000
# max      60.000000         29.000000     5.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count         4410.000000        4410.000000       4410.000000
# mean             2.687528          15.209524          0.793878
# std              2.495967           3.659108          0.851883
# min              0.000000          11.000000          0.000000
# 25%              1.000000          12.000000          0.000000
# 50%              2.000000          14.000000          1.000000
# 75%              4.000000          18.000000          1.000000
# max              9.000000          25.000000          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# count        4410.000000            4410.000000     4410.000000
# mean           11.277324               2.799320        7.008163
# std             7.774490               1.288978        6.125135
# min             0.000000               0.000000        0.000000
# 25%             6.000000               2.000000        3.000000
# 50%            10.000000               3.000000        5.000000
# 75%            15.000000               3.000000        9.000000
# max            40.000000               6.000000       40.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# count              4410.000000           4410.000000              4410.000000
# mean                  2.187755              4.123129                 2.725170
# std                   3.221699              3.567327                 1.089852
# min                   0.000000              0.000000                 1.000000
# 25%                   0.000000              2.000000                 2.000000
# 50%                   1.000000              3.000000                 3.000000
# 75%                   3.000000              7.000000                 4.000000
# max                  15.000000             17.000000                 4.000000
#
#        JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# count      4410.000000      4410.000000     4410.000000        4410.000000
# mean          2.734014         2.763492        2.729932           3.153741
# std           1.102071         0.703541        0.711400           0.360742
# min           1.000000         1.000000        1.000000           3.000000
# 25%           2.000000         2.000000        2.000000           3.000000
# 50%           3.000000         3.000000        3.000000           3.000000
# 75%           4.000000         3.000000        3.000000           3.000000
# max           4.000000         4.000000        4.000000           4.000000

# %% [markdown]
# ## <font color='0C2054'> Correlación </font>

# %%
nc = d2015.select_dtypes(include=[np.number])
plt.figure(figsize=(20, 20))
sns.heatmap(nc.corr(), annot=True, fmt='.2f', cmap='coolwarm', cbar=True, square=True, linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# ## <font color='0C2054'> Histograma

# %%
# Explorar variables numéricas con histograma
fig=nc.hist(bins=50, figsize=(40,30),grid=False,ec='black')
plt.show()

# %% [markdown]
# # <font color='0C2054'> <b> Análisis variables categóricas

# %% [markdown]
# ## <font color='0C2054'> Descripción

# %%
d2015.describe(include="object")
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            4410                    4410           4410   4410
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Attrition
# count              4410          4410      4410
# unique                9             3         2
# top     Sales Executive       Married        No
# freq                978          2019      3760

# %%
cc = d2015.select_dtypes(include=['object'])

#resumen de las variables categoricas para observar el balanceo de las categoricas

def cat_summary(dataframe, col_name, plot=False):
    print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                        'Ratio': 100 * dataframe[col_name].value_counts() / len(dataframe)}))
    print('##########################################')
    if plot:
        plt.figure(figsize=(12,6))
        sns.countplot(x=dataframe[col_name], data=dataframe)
        plt.show(block=True)

cat_cols = [col for col in cc.columns if cc[col].dtypes == "O"]
for col in cat_cols:
    cat_summary(cc, col, plot=False)
# Out:
#                    BusinessTravel      Ratio
# BusinessTravel
# Travel_Rarely                3129  70.952381
# Travel_Frequently             831  18.843537
# Non-Travel                    450  10.204082
# ##########################################
#                         Department      Ratio
# Department
# Research & Development        2883  65.374150
# Sales                         1338  30.340136
# Human Resources                189   4.285714
# ##########################################
#                   EducationField      Ratio
# EducationField
# Life Sciences               1818  41.224490
# Medical                     1392  31.564626
# Marketing                    477  10.816327
# Technical Degree             396   8.979592
# Other                        246   5.578231
# Human Resources               81   1.836735
# ##########################################
#         Gender  Ratio
# Gender
# Male      2646   60.0
# Female    1764   40.0
# ##########################################
#                            JobRole      Ratio
# JobRole
# Sales Executive                978  22.176871
# Research Scientist             876  19.863946
# Laboratory Technician          777  17.619048
# Manufacturing Director         435   9.863946
# Healthcare Representative      393   8.911565
# Manager                        306   6.938776
# Sales Representative           249   5.646259
# Research Director              240   5.442177
# Human Resources                156   3.537415
# ##########################################
#                MaritalStatus      Ratio
# MaritalStatus
# Married                 2019  45.782313
# Single                  1410  31.972789
# Divorced                 981  22.244898
# ##########################################
#            Attrition      Ratio
# Attrition
# No              3760  85.260771
# Yes              650  14.739229
# ##########################################

# %% [markdown]
# ## <font color='0C2054'> Gráficas

# %%
# Graficos para la comparación de las variables categoricas

# Definir el número de filas y columnas para los subplots
num_rows = 3
num_cols = 3

# Crear una figura y ejes de subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))

# Aplanar los ejes de los subplots para facilitar el bucle
axes = axes.flatten()

# Iterar sobre las variables categóricas y trazar gráficos de barras apiladas
for i, col in enumerate(cc.columns):
    ax = axes[i]
    crosstab = pd.crosstab(cc[col], d2015['Attrition'])
    crosstab.plot(kind='bar', stacked=True, ax=ax, color=['skyblue', 'orange'])
    ax.set_title(col)
    ax.set_xlabel('Category')
    ax.set_ylabel('Count')
    ax.tick_params(axis='x', rotation=45)
    ax.legend(title='Attrition')

# Ajustar el diseño y mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# #<font color='0C2054'><b>Conversión a dummies</font></b>

# %% [markdown]
# ## <font color='0C2054'>2015</font>

# %%
# Se crea copia al df
dummies2015 = d2015.copy()

# %%
# Se dentifican las variables categóricas
cat_2015 = dummies2015.select_dtypes(include=['object']).columns

# Iterar a través de las columnas categóricas y mostrar las categorías únicas
for column in cat_2015:
    unique_categories = dummies2015[column].unique()
    print(f'Categorías en "{column}": {unique_categories}')
# Out:
# Categorías en "BusinessTravel": ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Categorías en "Department": ['Sales' 'Research & Development' 'Human Resources']
# Categorías en "EducationField": ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Categorías en "Gender": ['Female' 'Male']
# Categorías en "JobRole": ['Healthcare Representative' 'Research Scientist' 'Sales Executive'
#  'Human Resources' 'Research Director' 'Laboratory Technician'
#  'Manufacturing Director' 'Sales Representative' 'Manager']
# Categorías en "MaritalStatus": ['Married' 'Single' 'Divorced']
# Categorías en "Attrition": ['No' 'Yes']

# %%
# Crear un objeto LabelEncoder
le = LabelEncoder()

# Iterar a través de las columnas categóricas y aplicar LabelEncoder si hay 2 categorías
for column in cat_2015:
    if len(dummies2015[column].unique()) == 2:  # Verificar si hay solo 2 categorías
       dummies2015[column] = le.fit_transform(dummies2015[column])

# Variables con mas de 2 categorias
dummies_2015 = pd.get_dummies(dummies2015)

# %%
dummies_2015
# Out:
#       Age  DistanceFromHome  Education  Gender  JobLevel  MonthlyIncome  \
# 0      51                 6          2       0         1         131160
# 1      31                10          1       0         1          41890
# 2      32                17          4       1         4         193280
# 3      38                 2          5       1         3          83210
# 4      32                10          1       1         1          23420
# ...   ...               ...        ...     ...       ...            ...
# 4405   42                 5          4       0         1          60290
# 4406   29                 2          4       1         1          26790
# 4407   25                25          2       1         2          37020
# 4408   42                18          2       1         1          23980
# 4409   40                28          3       1         2          54680
#
#       NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# 0                    1.0                 11                 0
# 1                    0.0                 23                 1
# 2                    1.0                 15                 3
# 3                    3.0                 11                 3
# 4                    4.0                 12                 2
# ...                  ...                ...               ...
# 4405                 3.0                 17                 1
# 4406                 2.0                 15                 0
# 4407                 0.0                 20                 0
# 4408                 0.0                 14                 1
# 4409                 0.0                 12                 0
#
#       TotalWorkingYears  ...  JobRole_Laboratory Technician  JobRole_Manager  \
# 0                   1.0  ...                          False            False
# 1                   6.0  ...                          False            False
# 2                   5.0  ...                          False            False
# 3                  13.0  ...                          False            False
# 4                   9.0  ...                          False            False
# ...                 ...  ...                            ...              ...
# 4405               10.0  ...                          False            False
# 4406               10.0  ...                           True            False
# 4407                5.0  ...                          False            False
# 4408               10.0  ...                           True            False
# 4409               10.0  ...                           True            False
#
#       JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                              False                      False
# 1                              False                      False
# 2                              False                      False
# 3                              False                      False
# 4                              False                      False
# ...                              ...                        ...
# 4405                           False                      False
# 4406                           False                      False
# 4407                           False                      False
# 4408                           False                      False
# 4409                           False                      False
#
#       JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                          False                    False
# 1                           True                    False
# 2                          False                     True
# 3                          False                    False
# 4                          False                     True
# ...                          ...                      ...
# 4405                        True                    False
# 4406                       False                    False
# 4407                       False                     True
# 4408                       False                    False
# 4409                       False                    False
#
#       JobRole_Sales Representative  MaritalStatus_Divorced  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 4405                         False                   False
# 4406                         False                    True
# 4407                         False                   False
# 4408                         False                    True
# 4409                         False                    True
#
#       MaritalStatus_Married  MaritalStatus_Single
# 0                      True                 False
# 1                     False                  True
# 2                      True                 False
# 3                      True                 False
# 4                     False                  True
# ...                     ...                   ...
# 4405                  False                  True
# 4406                  False                 False
# 4407                   True                 False
# 4408                  False                 False
# 4409                  False                 False
#
# [4410 rows x 44 columns]

# %%
dummies_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                4410 non-null   int64
#  1   DistanceFromHome                   4410 non-null   int64
#  2   Education                          4410 non-null   int64
#  3   Gender                             4410 non-null   int64
#  4   JobLevel                           4410 non-null   int64
#  5   MonthlyIncome                      4410 non-null   int64
#  6   NumCompaniesWorked                 4410 non-null   float64
#  7   PercentSalaryHike                  4410 non-null   int64
#  8   StockOptionLevel                   4410 non-null   int64
#  9   TotalWorkingYears                  4410 non-null   float64
#  10  TrainingTimesLastYear              4410 non-null   int64
#  11  YearsAtCompany                     4410 non-null   int64
#  12  YearsSinceLastPromotion            4410 non-null   int64
#  13  YearsWithCurrManager               4410 non-null   int64
#  14  EnvironmentSatisfaction            4410 non-null   float64
#  15  JobSatisfaction                    4410 non-null   float64
#  16  WorkLifeBalance                    4410 non-null   float64
#  17  JobInvolvement                     4410 non-null   int64
#  18  PerformanceRating                  4410 non-null   int64
#  19  Attrition                          4410 non-null   int64
#  20  BusinessTravel_Non-Travel          4410 non-null   bool
#  21  BusinessTravel_Travel_Frequently   4410 non-null   bool
#  22  BusinessTravel_Travel_Rarely       4410 non-null   bool
#  23  Department_Human Resources         4410 non-null   bool
#  24  Department_Research & Development  4410 non-null   bool
#  25  Department_Sales                   4410 non-null   bool
#  26  EducationField_Human Resources     4410 non-null   bool
#  27  EducationField_Life Sciences       4410 non-null   bool
#  28  EducationField_Marketing           4410 non-null   bool
#  29  EducationField_Medical             4410 non-null   bool
#  30  EducationField_Other               4410 non-null   bool
#  31  EducationField_Technical Degree    4410 non-null   bool
#  32  JobRole_Healthcare Representative  4410 non-null   bool
#  33  JobRole_Human Resources            4410 non-null   bool
#  34  JobRole_Laboratory Technician      4410 non-null   bool
#  35  JobRole_Manager                    4410 non-null   bool
#  36  JobRole_Manufacturing Director     4410 non-null   bool
#  37  JobRole_Research Director          4410 non-null   bool
#  38  JobRole_Research Scientist         4410 non-null   bool
#  39  JobRole_Sales Executive            4410 non-null   bool
#  40  JobRole_Sales Representative       4410 non-null   bool
#  41  MaritalStatus_Divorced             4410 non-null   bool
#  42  MaritalStatus_Married              4410 non-null   bool
#  43  MaritalStatus_Single               4410 non-null   bool
# dtypes: bool(24), float64(5), int64(15)
# memory usage: 792.5 KB

# %% [markdown]
# ## <font color='0C2054'>2016</font>

# %%
# Se crea copia al df
dummies2016 = d2016.copy()

# %%
# Se dentifican las variables categóricas
cat_2016 = dummies2016.select_dtypes(include=['object']).columns

# Iterar a través de las columnas categóricas y mostrar las categorías únicas
for column in cat_2016:
    unique_categories = dummies2016[column].unique()
    print(f'Categorías en "{column}": {unique_categories}')
# Out:
# Categorías en "BusinessTravel": ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Categorías en "Department": ['Sales' 'Research & Development' 'Human Resources']
# Categorías en "EducationField": ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Categorías en "Gender": ['Female' 'Male']
# Categorías en "JobRole": ['Healthcare Representative' 'Research Scientist' 'Sales Executive'
#  'Human Resources' 'Research Director' 'Laboratory Technician'
#  'Manufacturing Director' 'Sales Representative' 'Manager']
# Categorías en "MaritalStatus": ['Married' 'Single' 'Divorced']

# %%
# Crear un objeto LabelEncoder
le = LabelEncoder()

# Iterar a través de las columnas categóricas y aplicar LabelEncoder si hay 2 categorías
for column in cat_2016:
    if len(dummies2016[column].unique()) == 2:  # Verificar si hay solo 2 categorías
       dummies2015[column] = le.fit_transform(dummies2016[column])

# Variables con mas de 2 categorias
dummies_2016 = pd.get_dummies(dummies2016)

# %%
dummies_2016
# Out:
#       Age  DistanceFromHome  Education  EmployeeID  JobLevel  MonthlyIncome  \
# 0      51                 6          2           1         1         131160
# 1      31                10          1        4412         1          41890
# 2      32                17          4           3         4         193280
# 3      38                 2          5           4         3          83210
# 4      32                10          1           5         1          23420
# ...   ...               ...        ...         ...       ...            ...
# 4405   42                 5          4        4406         1          60290
# 4406   29                 2          4        4407         1          26790
# 4407   25                25          2        4408         2          37020
# 4408   42                18          2        4409         1          23980
# 4409   40                28          3        4410         2          54680
#
#       NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# 0                    1.0                 11                 0
# 1                    0.0                 23                 1
# 2                    1.0                 15                 3
# 3                    3.0                 11                 3
# 4                    4.0                 12                 2
# ...                  ...                ...               ...
# 4405                 3.0                 17                 1
# 4406                 2.0                 15                 0
# 4407                 0.0                 20                 0
# 4408                 0.0                 14                 1
# 4409                 0.0                 12                 0
#
#       TotalWorkingYears  ...  JobRole_Laboratory Technician  JobRole_Manager  \
# 0                   1.0  ...                          False            False
# 1                   6.0  ...                          False            False
# 2                   5.0  ...                          False            False
# 3                  13.0  ...                          False            False
# 4                   9.0  ...                          False            False
# ...                 ...  ...                            ...              ...
# 4405               10.0  ...                          False            False
# 4406               10.0  ...                           True            False
# 4407                5.0  ...                          False            False
# 4408               10.0  ...                           True            False
# 4409               10.0  ...                           True            False
#
#       JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                              False                      False
# 1                              False                      False
# 2                              False                      False
# 3                              False                      False
# 4                              False                      False
# ...                              ...                        ...
# 4405                           False                      False
# 4406                           False                      False
# 4407                           False                      False
# 4408                           False                      False
# 4409                           False                      False
#
#       JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                          False                    False
# 1                           True                    False
# 2                          False                     True
# 3                          False                    False
# 4                          False                     True
# ...                          ...                      ...
# 4405                        True                    False
# 4406                       False                    False
# 4407                       False                     True
# 4408                       False                    False
# 4409                       False                    False
#
#       JobRole_Sales Representative  MaritalStatus_Divorced  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 4405                         False                   False
# 4406                         False                    True
# 4407                         False                   False
# 4408                         False                    True
# 4409                         False                    True
#
#       MaritalStatus_Married  MaritalStatus_Single
# 0                      True                 False
# 1                     False                  True
# 2                      True                 False
# 3                      True                 False
# 4                     False                  True
# ...                     ...                   ...
# 4405                  False                  True
# 4406                  False                 False
# 4407                   True                 False
# 4408                  False                 False
# 4409                  False                 False
#
# [4410 rows x 45 columns]

# %%
dummies_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                4410 non-null   int64
#  1   DistanceFromHome                   4410 non-null   int64
#  2   Education                          4410 non-null   int64
#  3   EmployeeID                         4410 non-null   int64
#  4   JobLevel                           4410 non-null   int64
#  5   MonthlyIncome                      4410 non-null   int64
#  6   NumCompaniesWorked                 4410 non-null   float64
#  7   PercentSalaryHike                  4410 non-null   int64
#  8   StockOptionLevel                   4410 non-null   int64
#  9   TotalWorkingYears                  4410 non-null   float64
#  10  TrainingTimesLastYear              4410 non-null   int64
#  11  YearsAtCompany                     4410 non-null   int64
#  12  YearsSinceLastPromotion            4410 non-null   int64
#  13  YearsWithCurrManager               4410 non-null   int64
#  14  EnvironmentSatisfaction            4410 non-null   float64
#  15  JobSatisfaction                    4410 non-null   float64
#  16  WorkLifeBalance                    4410 non-null   float64
#  17  JobInvolvement                     4410 non-null   int64
#  18  PerformanceRating                  4410 non-null   int64
#  19  BusinessTravel_Non-Travel          4410 non-null   bool
#  20  BusinessTravel_Travel_Frequently   4410 non-null   bool
#  21  BusinessTravel_Travel_Rarely       4410 non-null   bool
#  22  Department_Human Resources         4410 non-null   bool
#  23  Department_Research & Development  4410 non-null   bool
#  24  Department_Sales                   4410 non-null   bool
#  25  EducationField_Human Resources     4410 non-null   bool
#  26  EducationField_Life Sciences       4410 non-null   bool
#  27  EducationField_Marketing           4410 non-null   bool
#  28  EducationField_Medical             4410 non-null   bool
#  29  EducationField_Other               4410 non-null   bool
#  30  EducationField_Technical Degree    4410 non-null   bool
#  31  Gender_Female                      4410 non-null   bool
#  32  Gender_Male                        4410 non-null   bool
#  33  JobRole_Healthcare Representative  4410 non-null   bool
#  34  JobRole_Human Resources            4410 non-null   bool
#  35  JobRole_Laboratory Technician      4410 non-null   bool
#  36  JobRole_Manager                    4410 non-null   bool
#  37  JobRole_Manufacturing Director     4410 non-null   bool
#  38  JobRole_Research Director          4410 non-null   bool
#  39  JobRole_Research Scientist         4410 non-null   bool
#  40  JobRole_Sales Executive            4410 non-null   bool
#  41  JobRole_Sales Representative       4410 non-null   bool
#  42  MaritalStatus_Divorced             4410 non-null   bool
#  43  MaritalStatus_Married              4410 non-null   bool
#  44  MaritalStatus_Single               4410 non-null   bool
# dtypes: bool(26), float64(5), int64(14)
# memory usage: 766.7 KB

# %% [markdown]
# #<font color='0C2054'><b>Exportación</font></b>

# %%
## Se exportan los DataFrame a archivos csv
dummies_2015.to_csv('/content/drive/MyDrive/AA/Analitica-en-recursos-humanos/Datos/dummies2015', index=False)
dummies_2016.to_csv('/content/drive/MyDrive/AA/Analitica-en-recursos-humanos/Datos/dummies2016', index=False)
